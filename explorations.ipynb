# %% [markdown]
# # hej

# %%
import sys

print(sys.executable)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\jonat\OneDrive\Skrivbord\Everything\Utveckling\AI-Tactical-Scout\.venv\Scripts\python.exe
# c:\Users\jonat\OneDrive\Skrivbord\Everything\Utveckling\AI-Tactical-Scout\.venv\Scripts\python.exe: No module named pip

# %%
# %pip install pandas
from src.backend.constants import VECTOR_DB_PATH
import lancedb


vector_db = lancedb.connect(VECTOR_DB_PATH)

df = vector_db["players"].to_pandas()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\jonat\OneDrive\Skrivbord\Everything\Utveckling\AI-Tactical-Scout\.venv\Scripts\python.exe: No module named pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 8
#       3 import lancedb
#       6 vector_db = lancedb.connect(VECTOR_DB_PATH)
# ----> 8 df = vector_db["players"].to_pandas()
#
# File c:\Users\jonat\OneDrive\Skrivbord\Everything\Utveckling\AI-Tactical-Scout\.venv\Lib\site-packages\lancedb\table.py:2038, in LanceTable.to_pandas(self)
#    2031 def to_pandas(self) -> "pd.DataFrame":
#    2032     """Return the table as a pandas DataFrame.
#    2033
#    2034     Returns
#    2035     -------
#    2036     pd.DataFrame
#    2037     """
# -> 2038     return self.to_arrow().to_pandas()
#
# ...
